# %% [markdown]
# <a href="https://colab.research.google.com/github/XFDTS/GEOG5990M_Final_Project/blob/main/GEOG5990M_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GEOG5990M Final Assignment
#
# Student ID number:201886391

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rmi = pd.read_csv('Residential_Mobility_Index.csv')

# %%
student_ea = pd.read_csv('student_ea.csv')

# %%
student_ea.head()
# Out:
#   Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 0                           E01011264                     Leeds 011A
# 1                           E01011264                     Leeds 011A
# 2                           E01011264                     Leeds 011A
# 3                           E01011264                     Leeds 011A
# 4                           E01011264                     Leeds 011A
#
#                             Economic activity status  Observation
# 0                                     Does not apply          179
# 1  Economically active (excluding full-time stude...          136
# 2  Economically active (excluding full-time stude...          351
# 3  Economically active (excluding full-time stude...            2
# 4  Economically active (excluding full-time stude...            5

# %%
rmi.head()
# Out:
#        area  chn1997  chn1998  chn1999  chn2000  chn2001  chn2002  chn2003  \
# 0  95AA01S1    1.000    1.000    1.000    1.000    1.000    1.000    1.000
# 1  95AA01S2    0.663    0.651    0.636    0.629    0.618    0.603    0.590
# 2  95AA01S3    0.700    0.688    0.671    0.663    0.653    0.633    0.611
# 3  95AA02W1    0.591    0.576    0.560    0.549    0.542    0.537    0.534
# 4  95AA03W1    0.602    0.591    0.586    0.584    0.581    0.569    0.554
#
#    chn2004  chn2005  ...  chn2014  chn2015  chn2016  chn2017  chn2018  \
# 0    1.000    1.000  ...    1.000    0.969    0.928    0.914    0.879
# 1    0.569    0.541  ...    0.416    0.397    0.373    0.336    0.287
# 2    0.591    0.570  ...    0.453    0.435    0.412    0.367    0.310
# 3    0.529    0.524  ...    0.387    0.362    0.331    0.297    0.262
# 4    0.541    0.524  ...    0.398    0.371    0.337    0.304    0.270
#
#    chn2019  chn2020  chn2021  chn2022  chn2023
# 0    0.799    0.723    0.537    0.290        0
# 1    0.256    0.244    0.186    0.102        0
# 2    0.279    0.266    0.182    0.072        0
# 3    0.243    0.233    0.172    0.087        0
# 4    0.252    0.244    0.177    0.081        0
#
# [5 rows x 28 columns]

# %%
student_ea.describe()
# Out:
#        Observation
# count  9198.000000
# mean     80.833007
# std     137.858207
# min       0.000000
# 25%       4.000000
# 50%      25.000000
# 75%      72.000000
# max    2497.000000

# %%
rmi.describe()
# Out:
#             chn1997       chn1998       chn1999       chn2000       chn2001  \
# count  42619.000000  42619.000000  42619.000000  42619.000000  42619.000000
# mean       0.689110      0.673903      0.654520      0.639123      0.621288
# std        0.118594      0.118496      0.119099      0.119532      0.120880
# min        0.231000      0.214000      0.199000      0.188000      0.174000
# 25%        0.608000      0.593000      0.572000      0.557000      0.538000
# 50%        0.684000      0.668000      0.649000      0.633000      0.614000
# 75%        0.764000      0.748000      0.729000      0.713000      0.695000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#             chn2002       chn2003       chn2004       chn2005       chn2006  \
# count  42619.000000  42619.000000  42619.000000  42619.000000  42619.000000
# mean       0.598203      0.578303      0.559791      0.541285      0.521789
# std        0.123715      0.126062      0.127883      0.128651      0.129383
# min        0.157000      0.145000      0.132000      0.118000      0.108000
# 25%        0.513000      0.491000      0.471000      0.451000      0.431000
# 50%        0.590000      0.569000      0.550000      0.530000      0.509000
# 75%        0.673000      0.654000      0.635000      0.617000      0.598000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...       chn2014       chn2015       chn2016       chn2017  \
# count  ...  42619.000000  42619.000000  42619.000000  42619.000000
# mean   ...      0.344240      0.325886      0.307138      0.273219
# std    ...      0.126939      0.125067      0.123287      0.115394
# min    ...      0.049000      0.046000      0.040000      0.031000
# 25%    ...      0.256000      0.239000      0.221000      0.194000
# 50%    ...      0.321000      0.302000      0.283000      0.249000
# 75%    ...      0.406000      0.385000      0.364000      0.324000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#             chn2018       chn2019       chn2020       chn2021       chn2022  \
# count  42619.000000  42619.000000  42619.000000  42619.000000  42619.000000
# mean       0.223909      0.192267      0.170231      0.133496      0.087132
# std        0.103086      0.095335      0.088860      0.074293      0.052823
# min        0.022000      0.019000      0.010000      0.003000      0.001000
# 25%        0.154000      0.129000      0.112000      0.085000      0.054000
# 50%        0.200000      0.169000      0.148000      0.115000      0.074000
# 75%        0.265000      0.229000      0.203000      0.159000      0.104000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        chn2023
# count  42619.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
#
# [8 rows x 27 columns]

# %%
student_ea.info() #check for missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9198 entries, 0 to 9197
# Data columns (total 4 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Lower layer Super Output Areas Code  9198 non-null   object
#  1   Lower layer Super Output Areas       9198 non-null   object
#  2   Economic activity status             9198 non-null   object
#  3   Observation                          9198 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 287.6+ KB

# %%
rmi.info() #check for missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42619 entries, 0 to 42618
# Data columns (total 28 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   area     42619 non-null  object
#  1   chn1997  42619 non-null  float64
#  2   chn1998  42619 non-null  float64
#  3   chn1999  42619 non-null  float64
#  4   chn2000  42619 non-null  float64
#  5   chn2001  42619 non-null  float64
#  6   chn2002  42619 non-null  float64
#  7   chn2003  42619 non-null  float64
#  8   chn2004  42619 non-null  float64
#  9   chn2005  42619 non-null  float64
#  10  chn2006  42619 non-null  float64
#  11  chn2007  42619 non-null  float64
#  12  chn2008  42619 non-null  float64
#  13  chn2009  42619 non-null  float64
#  14  chn2010  42619 non-null  float64
#  15  chn2011  42619 non-null  float64
#  16  chn2012  42619 non-null  float64
#  17  chn2013  42619 non-null  float64
#  18  chn2014  42619 non-null  float64
#  19  chn2015  42619 non-null  float64
#  20  chn2016  42619 non-null  float64
#  21  chn2017  42619 non-null  float64
#  22  chn2018  42619 non-null  float64
#  23  chn2019  42619 non-null  float64
#  24  chn2020  42619 non-null  float64
#  25  chn2021  42619 non-null  float64
#  26  chn2022  42619 non-null  float64
#  27  chn2023  42619 non-null  int64
# dtypes: float64(26), int64(1), object(1)
# memory usage: 9.1+ MB

# %%
student_ea.isnull().sum() #check for missing values
# Out:
# Lower layer Super Output Areas Code    0
# Lower layer Super Output Areas         0
# Economic activity status               0
# Observation                            0
# dtype: int64

# %%
rmi.isnull().sum() #check for missing values
# Out:
# area       0
# chn1997    0
# chn1998    0
# chn1999    0
# chn2000    0
# chn2001    0
# chn2002    0
# chn2003    0
# chn2004    0
# chn2005    0
# chn2006    0
# chn2007    0
# chn2008    0
# chn2009    0
# chn2010    0
# chn2011    0
# chn2012    0
# chn2013    0
# chn2014    0
# chn2015    0
# chn2016    0
# chn2017    0
# chn2018    0
# chn2019    0
# chn2020    0
# chn2021    0
# chn2022    0
# chn2023    0
# dtype: int64

# %% [markdown]
# This study utilized two open-source datasets, one of which is economic activity status data from the 2021 Census. This data is divided by LSOAs (Lower Super Output Area) for regional classification, with each LSOA containing various statuses of economic activity. Data exploration revealed that the dataset includes the number of people with different statuses of economic activity in each LSOA for the year 2021. It contains a total of 9,198 records with no missing values, the maximum value being 2,497 and the minimum being 0.
#
# The other dataset is residential mobility index for the city of Leeds, sourced from the CDRC Residential Mobility Index provided by the Consumer Data Research Centre. “Residential mobility ("Population Churn") is estimated at the household level. Households’ start and end dates are extracted from individual level data by combining individuals that at any point in time have shared time together in the same property or have a shared surname in the same property. First household member determines the ‘start’ date (household identified as moving in), last household member determines the ‘end’ date (household identified as moving out)” [1]. Data exploration revealed that this dataset contains UK housing mobility data from 1997 to 2023 and is spatially divided by LSOAs. The dataset includes data from 42,619 LSOAs over 26 years, with no missing values, and the index ranges between 0 and 1. However, there is an issue with the data for 2023, as the housing mobility index for every LSOA in that year is zero. Because the other dataset, economic activity status data used in this study, is from 2021, issues with data from different years in this dataset will not affect the outcomes of this research.

# %%
student_ea = student_ea[student_ea['Economic activity status'].isin(['Economically active and a full-time student','Economically inactive: Student'])]
# only include two kinds of student economic activity statuses

# %%
student_ea = student_ea[student_ea['Lower layer Super Output Areas'].str.contains('leeds', case=False)] # select only the data for Leeds

# %%
student_ea.head()
# Out:
#    Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 15                           E01011264                     Leeds 011A
# 17                           E01011264                     Leeds 011A
# 36                           E01011265                     Leeds 009A
# 38                           E01011265                     Leeds 009A
# 57                           E01011266                     Leeds 008A
#
#                        Economic activity status  Observation
# 15  Economically active and a full-time student           15
# 17               Economically inactive: Student           32
# 36  Economically active and a full-time student           18
# 38               Economically inactive: Student           66
# 57  Economically active and a full-time student           27

# %%
student_ea.describe()
# Out:
#        Observation
# count   876.000000
# mean     69.369863
# std     141.095826
# min       3.000000
# 25%      23.000000
# 50%      39.000000
# 75%      60.000000
# max    2497.000000

# %%
student_ea.columns
# Out:
# Index(['Lower layer Super Output Areas Code', 'Lower layer Super Output Areas',
#        'Economic activity status', 'Observation'],
#       dtype='object')

# %%
sns.catplot(x='Economic activity status', y='Observation', data=student_ea);
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels 45 degrees for better readability
plt.tight_layout()

# %%
student_ea.loc[student_ea['Lower layer Super Output Areas Code']=='E01011678']
# Out:
#      Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 7995                           E01011678                     Leeds 063B
# 7997                           E01011678                     Leeds 063B
#
#                          Economic activity status  Observation
# 7995  Economically active and a full-time student          962
# 7997               Economically inactive: Student         2497

# %%
student_ea.loc[student_ea['Observation']==2497]
# Out:
#      Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 7997                           E01011678                     Leeds 063B
#
#             Economic activity status  Observation
# 7997  Economically inactive: Student         2497

# %%
rmi.columns
# Out:
# Index(['area', 'chn1997', 'chn1998', 'chn1999', 'chn2000', 'chn2001',
#        'chn2002', 'chn2003', 'chn2004', 'chn2005', 'chn2006', 'chn2007',
#        'chn2008', 'chn2009', 'chn2010', 'chn2011', 'chn2012', 'chn2013',
#        'chn2014', 'chn2015', 'chn2016', 'chn2017', 'chn2018', 'chn2019',
#        'chn2020', 'chn2021', 'chn2022', 'chn2023'],
#       dtype='object')

# %%
rmi=rmi.drop(columns=['chn1997', 'chn1998', 'chn1999', 'chn2000', 'chn2001',
       'chn2002', 'chn2003', 'chn2004', 'chn2005', 'chn2006', 'chn2007',
       'chn2008', 'chn2009', 'chn2010', 'chn2011', 'chn2012', 'chn2013',
       'chn2014', 'chn2015', 'chn2016', 'chn2017', 'chn2018', 'chn2019',
       'chn2020', 'chn2022', 'chn2023'])

# %%
rmi.describe()
# Out:
#             chn2021
# count  42619.000000
# mean       0.133496
# std        0.074293
# min        0.003000
# 25%        0.085000
# 50%        0.115000
# 75%        0.159000
# max        1.000000

# %%
rmi.columns
# Out:
# Index(['area', 'chn2021'], dtype='object')

# %%
data_m = pd.merge(student_ea, rmi, left_on='Lower layer Super Output Areas Code', right_on='area', how='inner') # merge dataset based on LSOA codes

# %%
data_m.head()
# Out:
#   Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 0                           E01011264                     Leeds 011A
# 1                           E01011264                     Leeds 011A
# 2                           E01011265                     Leeds 009A
# 3                           E01011265                     Leeds 009A
# 4                           E01011266                     Leeds 008A
#
#                       Economic activity status  Observation       area  \
# 0  Economically active and a full-time student           15  E01011264
# 1               Economically inactive: Student           32  E01011264
# 2  Economically active and a full-time student           18  E01011265
# 3               Economically inactive: Student           66  E01011265
# 4  Economically active and a full-time student           27  E01011266
#
#    chn2021
# 0    0.047
# 1    0.047
# 2    0.196
# 3    0.196
# 4    0.151

# %%
data_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 876 entries, 0 to 875
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Lower layer Super Output Areas Code  876 non-null    object
#  1   Lower layer Super Output Areas       876 non-null    object
#  2   Economic activity status             876 non-null    object
#  3   Observation                          876 non-null    int64
#  4   area                                 876 non-null    object
#  5   chn2021                              876 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 41.2+ KB

# %%
sns.jointplot(data=data_m, x="Observation", y="chn2021", kind="kde")

# %%
data_m.describe()
# Out:
#        Observation     chn2021
# count   876.000000  876.000000
# mean     69.369863    0.101632
# std     141.095826    0.061463
# min       3.000000    0.029000
# 25%      23.000000    0.064000
# 50%      39.000000    0.085000
# 75%      60.000000    0.116000
# max    2497.000000    0.443000

# %% [markdown]
# Since the research area for this study is Leeds City and the target group is students, an initial data cleaning step is necessary to remove irrelevant parts of the dataset to make the subsequent data processing more efficient. In the economic activity status data, only two variables needed to be retained: “Economically active and a full-time student” and “Economically inactive: Student.” These two variables represent the number of students with different economic activity statuses within each LSOA area. In addition, data for the city of Leeds was selected using the “Lower Layer Super Output Areas” field in the dataset. Since the student economic activity data is from 2021, only the “chn2021” field was retained from the residential mobility index dataset to ensure consistency in the research data. This variable: “chn2021,” represents the residential mobility index for each LSOA in 2021.
#
# Real-world data is often inconsistent, duplicated, inaccurate, incomplete, or stale. Such data usually leads to misleading or biased analysis results in research [2]. There is a significant disparity between the maximum and minimum values in the economic activity status data according to data exploration. To further examine the data distribution and identify outliers, a strip plot generated by seaborn.catplot() was used for visualization. This function can display the relationship between numerical values and one or more categorical variables [3]. Through the visualization of student numbers across different economic statuses, a notably large outlier was found in both the economically active and inactive data categories. Meanwhile, further data exploration showed that both outliers appear in the same LSOA: E01011678. According to information found through web searches, this area is located near some universities and contains a large number of student accommodations. Therefore, these two values are considered valid values and were retained. This kind of value is rare in the dataset, but valid observations that reflect the real characteristics of the target population should not be altered [4].
#
# Because the residential mobility dataset retained only the LSOA and the 2021 residential mobility index fields after the initial cleaning, it is not possible to directly filter for data specific to Leeds, nor is it easy for visualization. The cleaned dataset containing only student economic activity status data for Leeds was joined with the residential mobility dataset, and the merged data was then used for further analysis. The datasets were joined using the two fields containing LSOA codes. Data exploration showed that the data does not contain excessively large or small values. Therefore, the Kernel density estimates plot was applied to visualize the concentration patterns in the residential mobility data [5]. Based on the visualization, the data is relatively concentrated and primarily falls within the range of 0 to 0.2. Because the data is well-distributed and contains no outliers, no further data cleaning is required.

# %%
colors = ["#3498db", "#e67e22"]
plot = sns.lmplot(
        data=data_m,
    x='chn2021',
    y='Observation',
    hue='Economic activity status',
    height=7,
    aspect=1.3,
    markers=['^', 'o'],             # Triangle and circle markers for the groups
    scatter_kws={'alpha': 0.6, 's': 30},  # Transparency and size of points
    line_kws={'linewidth': 2}       # Thickness of regression lin
)

# Add plot title and axis labels
plot.fig.suptitle("The relationship between Residential Mobility Index and different economically activity statuses Student", fontsize=16)
plot.set_axis_labels("Residential Mobility Index", "Count", fontsize=13)
# Adjust spacing to prevent title from overlapping
plot.fig.subplots_adjust(top=0.92)
plt.show();

# %% [markdown]
# The merged dataset contains residential mobility index data and the number of students in two economic activity statuses for each LSOA in Leeds. By visualizing this dataset, it is possible to compare which economic activity statuses of students are more affected by residential mobility in Leeds. This study applies a linear regression model to analyze the relationships between variables. This model can simply and intuitively demonstrate the relationship between independent and dependent variables [6]. Moreover, since the dataset used in this study has a high degree of concentration, the regression model can more accurately reflect the impact of the independent variables on the dependent variable. The data was visualized using scatter plots with fitted linear regression lines generated by the seaborn.implot function. This function can perform regression analysis separately on different categories of data based on conditions, making it suitable for the merged dataset in this study [7]. In the visualization process, since the data was divided into two categories, colors with high distinction were used [8]. To enhance the accessibility of the visualization and ensure it is readable for all audiences, orange and blue were used as contrasting colors, along with different point shapes for distinction [9]. As shown in the plot, the orange points and regression line represent the impact of the residential mobility index on economically inactive students, while the blue color indicates its impact on economically active students. It can be concluded that the residential mobility index in Leeds is positively correlated with the number of students. Moreover, economically inactive students are more strongly affected by the residential mobility index.

# %%
# !pip install contextily
# !pip install geoplot
# !pip install git+https://github.com/pmdscully/geo_northarrow.git
# !pip install matplotlib-scalebar
# Out:
# Requirement already satisfied: contextily in /usr/local/lib/python3.11/dist-packages (1.6.2)
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from contextily) (3.10.0)
# Requirement already satisfied: mercantile in /usr/local/lib/python3.11/dist-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from contextily) (11.2.1)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.11/dist-packages (from contextily) (1.4.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from contextily) (2.32.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from contextily) (1.5.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from contextily) (2025.4.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.11/dist-packages (from mercantile->contextily) (8.2.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.11/dist-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio->contextily) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio->contextily) (2025.4.26)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.11/dist-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.11/dist-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->contextily) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->contextily) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->contextily) (2.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.17.0)
# Requirement already satisfied: geoplot in /usr/local/lib/python3.11/dist-packages (0.5.1)
# Requirement already satisfied: matplotlib>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from geoplot) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from geoplot) (0.13.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from geoplot) (2.2.2)
# Requirement already satisfied: geopandas>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from geoplot) (1.0.1)
# Requirement already satisfied: cartopy in /usr/local/lib/python3.11/dist-packages (from geoplot) (0.24.1)
# Requirement already satisfied: mapclassify>=2.1 in /usr/local/lib/python3.11/dist-packages (from geoplot) (2.8.1)
# Requirement already satisfied: contextily>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from geoplot) (1.6.2)
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (from contextily>=1.0.0->geoplot) (2.4.1)
# Requirement already satisfied: mercantile in /usr/local/lib/python3.11/dist-packages (from contextily>=1.0.0->geoplot) (1.2.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from contextily>=1.0.0->geoplot) (11.2.1)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.11/dist-packages (from contextily>=1.0.0->geoplot) (1.4.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from contextily>=1.0.0->geoplot) (2.32.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from contextily>=1.0.0->geoplot) (1.5.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from contextily>=1.0.0->geoplot) (2025.4.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from geopandas>=0.9.0->geoplot) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas>=0.9.0->geoplot) (0.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas>=0.9.0->geoplot) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas>=0.9.0->geoplot) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas>=0.9.0->geoplot) (2.1.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.11/dist-packages (from mapclassify>=2.1->geoplot) (3.4.2)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from mapclassify>=2.1->geoplot) (1.6.1)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.11/dist-packages (from mapclassify>=2.1->geoplot) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.2->geoplot) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.2->geoplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.2->geoplot) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.2->geoplot) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.2->geoplot) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.2->geoplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->geoplot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->geoplot) (2025.2)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.11/dist-packages (from cartopy->geoplot) (2.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyogrio>=0.7.2->geopandas>=0.9.0->geoplot) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->geoplot) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->mapclassify>=2.1->geoplot) (3.6.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy->contextily>=1.0.0->geoplot) (2.0)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.11/dist-packages (from mercantile->contextily>=1.0.0->geoplot) (8.2.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.11/dist-packages (from rasterio->contextily>=1.0.0->geoplot) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio->contextily>=1.0.0->geoplot) (25.3.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.11/dist-packages (from rasterio->contextily>=1.0.0->geoplot) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.11/dist-packages (from rasterio->contextily>=1.0.0->geoplot) (1.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->contextily>=1.0.0->geoplot) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->contextily>=1.0.0->geoplot) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->contextily>=1.0.0->geoplot) (2.4.0)
# Collecting git+https://github.com/pmdscully/geo_northarrow.git
#   Cloning https://github.com/pmdscully/geo_northarrow.git to /tmp/pip-req-build-u6urr635
#   Running command git clone --filter=blob:none --quiet https://github.com/pmdscully/geo_northarrow.git /tmp/pip-req-build-u6urr635
#   Resolved https://github.com/pmdscully/geo_northarrow.git to commit 963bdd271707a3bcaa47b2d83d92b88ae0b10950
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from geo_northarrow==0.2.0a0) (2.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from geo_northarrow==0.2.0a0) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from geo_northarrow==0.2.0a0) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from geo_northarrow==0.2.0a0) (3.10.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (from geo_northarrow==0.2.0a0) (1.0.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas->geo_northarrow==0.2.0a0) (0.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas->geo_northarrow==0.2.0a0) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->geo_northarrow==0.2.0a0) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->geo_northarrow==0.2.0a0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->geo_northarrow==0.2.0a0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->geo_northarrow==0.2.0a0) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geo_northarrow==0.2.0a0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geo_northarrow==0.2.0a0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geo_northarrow==0.2.0a0) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geo_northarrow==0.2.0a0) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geo_northarrow==0.2.0a0) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geo_northarrow==0.2.0a0) (3.2.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyogrio>=0.7.2->geopandas->geo_northarrow==0.2.0a0) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->geo_northarrow==0.2.0a0) (1.17.0)
# Requirement already satisfied: matplotlib-scalebar in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from matplotlib-scalebar) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->matplotlib-scalebar) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->matplotlib-scalebar) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->matplotlib-scalebar) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->matplotlib-scalebar) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->matplotlib-scalebar) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->matplotlib-scalebar) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->matplotlib-scalebar) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->matplotlib-scalebar) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->matplotlib-scalebar) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->matplotlib-scalebar) (1.17.0)

# %%
import geopandas as gpd
import matplotlib.colors as colors
import matplotlib.patches as mpatches
import contextily as ctx
from shapely import wkt
from geo_northarrow import add_north_arrow
from matplotlib_scalebar.scalebar import ScaleBar

# %%
inactive_student=data_m[data_m['Economic activity status'] == 'Economically inactive: Student']

# %%
inactive_student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 438 entries, 1 to 875
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Lower layer Super Output Areas Code  438 non-null    object
#  1   Lower layer Super Output Areas       438 non-null    object
#  2   Economic activity status             438 non-null    object
#  3   Observation                          438 non-null    int64
#  4   area                                 438 non-null    object
#  5   chn2021                              438 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 24.0+ KB

# %%
leeds_shp =gpd.read_file('https://github.com/FrancescaPontin/GEOG5990M/raw/refs/heads/main/data/week_20/Leeds.geojson')

# %%
leeds_shp.head()
# Out:
#      FID   LSOA21CD    LSOA21NM   BNG_E   BNG_N     LONG       LAT  \
# 0  10720  E01011264  Leeds 011A  420937  441836 -1.68306  53.87232
# 1  10721  E01011265  Leeds 009A  418988  441951 -1.71269  53.87343
# 2  10722  E01011266  Leeds 008A  417489  442615 -1.73545  53.87945
# 3  10723  E01011267  Leeds 009B  419641  442025 -1.70276  53.87407
# 4  10724  E01011268  Leeds 010A  420224  441935 -1.69390  53.87324
#
#                                GlobalID  \
# 0  14a73329-fc8f-464c-a4fa-1963baa35500
# 1  eda471dd-f408-4dab-917e-c5e188310b35
# 2  286c32c5-ef49-4ecc-a45e-57630c165c62
# 3  318cfaa3-9f08-4d61-a30e-82e903f3a7ba
# 4  049e79f0-cd9e-47dc-848b-b6d6fa6825ac
#
#                                             geometry
# 0  POLYGON ((421248.688 442315.812, 421284.072 44...
# 1  POLYGON ((418635 442559, 418637.555 442552.869...
# 2  POLYGON ((417783.688 443382.312, 417788.688 44...
# 3  POLYGON ((419607.843 442388.568, 419612.752 44...
# 4  POLYGON ((420442.406 442436.687, 420443.313 44...

# %%
merged_data = leeds_shp.merge(inactive_student, how='left',left_on='LSOA21CD',right_on='Lower layer Super Output Areas Code')

# %%
merged_data.head()
# Out:
#      FID   LSOA21CD    LSOA21NM   BNG_E   BNG_N     LONG       LAT  \
# 0  10720  E01011264  Leeds 011A  420937  441836 -1.68306  53.87232
# 1  10721  E01011265  Leeds 009A  418988  441951 -1.71269  53.87343
# 2  10722  E01011266  Leeds 008A  417489  442615 -1.73545  53.87945
# 3  10723  E01011267  Leeds 009B  419641  442025 -1.70276  53.87407
# 4  10724  E01011268  Leeds 010A  420224  441935 -1.69390  53.87324
#
#                                GlobalID  \
# 0  14a73329-fc8f-464c-a4fa-1963baa35500
# 1  eda471dd-f408-4dab-917e-c5e188310b35
# 2  286c32c5-ef49-4ecc-a45e-57630c165c62
# 3  318cfaa3-9f08-4d61-a30e-82e903f3a7ba
# 4  049e79f0-cd9e-47dc-848b-b6d6fa6825ac
#
#                                             geometry  \
# 0  POLYGON ((421248.688 442315.812, 421284.072 44...
# 1  POLYGON ((418635 442559, 418637.555 442552.869...
# 2  POLYGON ((417783.688 443382.312, 417788.688 44...
# 3  POLYGON ((419607.843 442388.568, 419612.752 44...
# 4  POLYGON ((420442.406 442436.687, 420443.313 44...
#
#   Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 0                           E01011264                     Leeds 011A
# 1                           E01011265                     Leeds 009A
# 2                           E01011266                     Leeds 008A
# 3                           E01011267                     Leeds 009B
# 4                           E01011268                     Leeds 010A
#
#          Economic activity status  Observation       area  chn2021
# 0  Economically inactive: Student         32.0  E01011264    0.047
# 1  Economically inactive: Student         66.0  E01011265    0.196
# 2  Economically inactive: Student         68.0  E01011266    0.151
# 3  Economically inactive: Student         68.0  E01011267    0.068
# 4  Economically inactive: Student         40.0  E01011268    0.056

# %%
merged_data.isnull().sum() #check for missing values
# Out:
# FID                                     0
# LSOA21CD                                0
# LSOA21NM                                0
# BNG_E                                   0
# BNG_N                                   0
# LONG                                    0
# LAT                                     0
# GlobalID                                0
# geometry                                0
# Lower layer Super Output Areas Code    50
# Lower layer Super Output Areas         50
# Economic activity status               50
# Observation                            50
# area                                   50
# chn2021                                50
# dtype: int64

# %%
merged_data.loc[merged_data['Observation'].isna()] #check for missing values location
# Out:
#        FID   LSOA21CD    LSOA21NM   BNG_E   BNG_N     LONG       LAT  \
# 438  30837  E01032487  Leeds 097F  436166  428622 -1.45300  53.75273
# 439  30838  E01032488  Leeds 097G  435768  428670 -1.45903  53.75319
# 440  30839  E01032489  Leeds 102F  426947  428065 -1.59286  53.74828
# 441  30840  E01032490  Leeds 102G  427323  427477 -1.58721  53.74297
# 442  30841  E01032491  Leeds 102H  427454  426840 -1.58528  53.73724
# 443  30842  E01032492  Leeds 102I  426801  427730 -1.59510  53.74527
# 444  30843  E01032493  Leeds 033F  425405  436680 -1.61553  53.82578
# 445  30844  E01032494  Leeds 033G  425061  437008 -1.62073  53.82875
# 446  30845  E01032496  Leeds 105F  432533  426892 -1.50828  53.73742
# 447  30846  E01032497  Leeds 099E  430293  429285 -1.54200  53.75906
# 448  30847  E01032498  Leeds 099F  429737  428524 -1.55051  53.75225
# 449  30848  E01032499  Leeds 067G  425876  433898 -1.60861  53.80076
# 450  30849  E01032500  Leeds 067H  426610  433694 -1.59748  53.79889
# 451  30850  E01032501  Leeds 017E  424697  439295 -1.62608  53.84932
# 452  30851  E01032502  Leeds 017F  424855  438861 -1.62371  53.84541
# 453  30852  E01032503  Leeds 007E  423606  442156 -1.64244  53.87508
# 454  30853  E01032504  Leeds 007F  426244  442472 -1.60230  53.87780
# 455  30946  E01032606  Leeds 067I  425051  434140 -1.62112  53.80297
# 456  30947  E01032607  Leeds 067J  426609  433347 -1.59753  53.79577
# 457  30948  E01032608  Leeds 067K  426241  433697 -1.60308  53.79893
# 458  31162  E01032876  Leeds 109G  427765  437948 -1.57957  53.83706
# 459  31211  E01032946  Leeds 110G  428502  435829 -1.56856  53.81798
# 460  31259  E01033002  Leeds 055F  430405  434292 -1.53981  53.80405
# 461  31260  E01033003  Leeds 055G  430727  434411 -1.53491  53.80510
# 462  31261  E01033008  Leeds 111A  429483  433792 -1.55386  53.79961
# 463  31262  E01033010  Leeds 111B  430272  433829 -1.54188  53.79990
# 464  31263  E01033011  Leeds 111C  430723  433454 -1.53507  53.79650
# 465  31264  E01033013  Leeds 082E  429076  432614 -1.56015  53.78905
# 466  31265  E01033015  Leeds 111D  429408  433175 -1.55506  53.79407
# 467  31266  E01033016  Leeds 111E  430127  432775 -1.54418  53.79044
# 468  31267  E01033021  Leeds 075E  431567  433334 -1.52227  53.79537
# 469  31277  E01033031  Leeds 064E  431137  434653 -1.52866  53.80726
# 470  31278  E01033033  Leeds 075F  431009  433345 -1.53074  53.79551
# 471  31279  E01033034  Leeds 075G  431086  433025 -1.52960  53.79263
# 472  31280  E01033035  Leeds 064F  431407  434220 -1.52460  53.80335
# 473  33035  E01035040  Leeds 044G  427297  436123 -1.58684  53.82068
# 474  33036  E01035041  Leeds 044H  427377  435762 -1.58566  53.81743
# 475  33037  E01035042  Leeds 055I  429088  435206 -1.55972  53.81234
# 476  33038  E01035043  Leeds 055J  429837  434638 -1.54840  53.80720
# 477  33039  E01035044  Leeds 063F  429155  434724 -1.55875  53.80801
# 478  33040  E01035045  Leeds 063G  428977  434368 -1.56149  53.80482
# 479  33041  E01035046  Leeds 082G  429918  432610 -1.54737  53.78896
# 480  33042  E01035047  Leeds 082H  429636  432498 -1.55166  53.78797
# 481  33043  E01035048  Leeds 099G  430979  428149 -1.53171  53.74881
# 482  33044  E01035049  Leeds 099H  431655  427823 -1.52149  53.74584
# 483  33045  E01035050  Leeds 105G  430214  426790 -1.54344  53.73664
# 484  33046  E01035051  Leeds 105H  431335  427174 -1.52641  53.74003
# 485  33047  E01035052  Leeds 105I  431014  426532 -1.53134  53.73427
# 486  33048  E01035053  Leeds 105J  432010  426253 -1.51627  53.73171
# 487  33049  E01035054  Leeds 112F  430907  432531 -1.53237  53.78820
#
#                                  GlobalID  \
# 438  5ed90e0b-5942-4b6c-b019-d1e508fd59b6
# 439  dec33186-bed2-4035-99f8-adee19b1d67d
# 440  674e2a3a-3b97-4599-84be-a5f0ef754e9b
# 441  62d38e2d-d611-4f6e-a71b-1e0585a430b9
# 442  bb44f498-291e-4115-aca6-b0cf469bb661
# 443  a914da80-450f-43d8-9984-a4aed01e489c
# 444  fce958a7-bafb-475c-b1fe-a26f65614c98
# 445  202107b9-bc76-4e1d-9c2c-6ea19b66f508
# 446  123f502d-f325-4bfd-989c-59b549a7c816
# 447  5c153390-e65c-4267-a0d6-f3e7aabc408e
# 448  d9a70cac-b74b-409b-abc1-4b57f079efa0
# 449  f4ae6d76-da6a-4b7e-9f64-ad9a3eef7104
# 450  e915ec26-001f-4661-929a-1affcffe5d63
# 451  604def36-75df-4794-8fad-8de17764c801
# 452  d9c3c514-8a94-4a5d-b7cf-caffef70bb34
# 453  61b31cb6-356f-47b3-9fe3-eff95406aaa0
# 454  6275dfef-1da5-4af5-9f8f-af75662e3b93
# 455  c1d3f442-d57a-49f7-9bd4-fa28ebcb5324
# 456  fee9bfac-fe11-4a0d-8aa4-f705732732bd
# 457  e78882f2-481d-4eef-b8db-46d85a814bbe
# 458  c8896d0e-ea5f-47b6-b339-bb34663c207b
# 459  ec1db425-4f39-4025-94dd-1f39706d40c1
# 460  b290094c-7958-49b6-8c1a-fb995fd6908d
# 461  28a04843-a7f6-4d8e-a235-b5631a340cf1
# 462  348112f8-be5b-4d7c-b57d-5f17730870b2
# 463  9ced41ce-385f-4cc2-b181-945a5408e654
# 464  0e272c90-843c-4f24-bc0f-1995c917182f
# 465  43792916-e121-4628-837f-f2a5cb1eb1ce
# 466  e99e9a5f-ed31-4be4-b309-b02f28c5603a
# 467  bd48f935-d28c-4a56-af09-a45ec3f90f4e
# 468  78ea40ba-9cb9-4e00-a300-156380aaeb82
# 469  bc21d89b-24b2-4319-9513-8d9dea9a912d
# 470  27309226-960d-4499-a146-4d2d7aad24a2
# 471  b3675063-6c5a-4dd6-b805-23d3559b8355
# 472  6b8a48d1-e314-40ab-be7e-b4dd41196613
# 473  e915ff4f-6497-4452-a76b-6aa3cbe3f02f
# 474  352ebff7-486e-42d6-8440-31f7e95e6fd1
# 475  94488c7b-6d60-495b-b013-5f5ae268779a
# 476  8434e184-899b-4831-bd4e-d556320a2204
# 477  ff6cded1-d3f1-4cc4-8b0c-fced84174a26
# 478  4c3dc56f-9c71-4c21-b4a6-8794ec0904bf
# 479  0c80f700-21ce-46dc-baa7-3e492ea8fc6b
# 480  25de9a56-ee9a-4e52-bd3c-5470b8fad2d0
# 481  8af610f5-9d30-4c49-8c6d-38cb6a7cda7d
# 482  9e6992aa-31be-4406-96f0-dc1c9d56fd43
# 483  b667dd4b-08ca-44db-9dda-151975c865fc
# 484  1f70231e-7d95-4348-8af5-93b39135f194
# 485  5f1e5ab8-2aec-4af0-9271-558e556b63ba
# 486  0be7990f-f591-4c6c-953b-adc431b812da
# 487  293f102a-adaf-46ca-af9e-9a51f4a912b3
#
#                                               geometry  \
# 438  POLYGON ((435978.454 428965.815, 435982.522 42...
# 439  POLYGON ((436260.913 429223.898, 436268.559 42...
# 440  POLYGON ((427466.616 428135.434, 427459.797 42...
# 441  POLYGON ((427574.872 427960.977, 427577.742 42...
# 442  POLYGON ((427779.325 427780.734, 427779.77 427...
# 443  POLYGON ((427512.946 428036.103, 427526.01 428...
# 444  POLYGON ((425158.092 436944.99, 425175.69 4369...
# 445  POLYGON ((425351.372 437517.271, 425353.5 4375...
# 446  POLYGON ((432391.328 427573.779, 432429.253 42...
# 447  POLYGON ((430600.936 429622.5, 430606.353 4296...
# 448  POLYGON ((429964.238 428799.896, 430101.503 42...
# 449  POLYGON ((426614 434310, 426618 434302, 426621...
# 450  POLYGON ((426703.24 433864.572, 426733.426 433...
# 451  POLYGON ((424955.296 439665.407, 424956.964 43...
# 452  POLYGON ((425063.016 439295.508, 425071.81 439...
# 453  POLYGON ((424873 444357, 424873.606 444349.878...
# 454  POLYGON ((427106.501 443244.187, 427112.799 44...
# 455  POLYGON ((424800.3 434439.001, 424806.906 4344...
# 456  POLYGON ((426204 433503, 426207 433500, 426208...
# 457  POLYGON ((426348.028 434002.123, 426354 434000...
# 458  POLYGON ((427209.906 438898.594, 427222 438897...
# 459  POLYGON ((428500 436185, 428508 436182, 428509...
# 460  POLYGON ((430414.904 434816.575, 430445.719 43...
# 461  POLYGON ((431115.233 434630.985, 431075 434576...
# 462  POLYGON ((429927 434278, 429924 434266, 429921...
# 463  POLYGON ((430324.094 434257.094, 430336.594 43...
# 464  POLYGON ((431181.674 433701.484, 431193.677 43...
# 465  POLYGON ((428965.5 433368.6, 428966.501 433367...
# 466  POLYGON ((429037.244 433533.271, 429037.5 4335...
# 467  POLYGON ((429738.004 433537.387, 429742.3 4335...
# 468  POLYGON ((431481.813 433625.187, 431496.095 43...
# 469  POLYGON ((431247.993 434763.757, 431270.884 43...
# 470  POLYGON ((431273.217 433457.108, 431270.477 43...
# 471  POLYGON ((430808 433241, 430814 433231, 430820...
# 472  POLYGON ((431646.452 434812.116, 431649 434812...
# 473  POLYGON ((427455.473 436298.086, 427455.228 43...
# 474  POLYGON ((427469.194 436004.514, 427469.883 43...
# 475  POLYGON ((429263.549 435539.35, 429265.113 435...
# 476  POLYGON ((429744.548 434856.224, 429743.346 43...
# 477  POLYGON ((429026.458 434951.366, 429098.161 43...
# 478  POLYGON ((429145 434529, 429185.001 434507, 42...
# 479  POLYGON ((429993 432661, 430000 432659, 430000...
# 480  POLYGON ((429648 432928, 429661 432925, 429666...
# 481  POLYGON ((431362 428526, 431366 428520, 431369...
# 482  POLYGON ((431592.813 428129.832, 431608.022 42...
# 483  POLYGON ((430986.896 427756.226, 430982.739 42...
# 484  POLYGON ((431044.305 427760.241, 431050.502 42...
# 485  POLYGON ((431312.508 427066, 431277.221 426958...
# 486  POLYGON ((432234.698 427047.143, 432235.065 42...
# 487  POLYGON ((430657.956 433169.095, 430686 433160...
#
#     Lower layer Super Output Areas Code Lower layer Super Output Areas  \
# 438                                 NaN                            NaN
# 439                                 NaN                            NaN
# 440                                 NaN                            NaN
# 441                                 NaN                            NaN
# 442                                 NaN                            NaN
# 443                                 NaN                            NaN
# 444                                 NaN                            NaN
# 445                                 NaN                            NaN
# 446                                 NaN                            NaN
# 447                                 NaN                            NaN
# 448                                 NaN                            NaN
# 449                                 NaN                            NaN
# 450                                 NaN                            NaN
# 451                                 NaN                            NaN
# 452                                 NaN                            NaN
# 453                                 NaN                            NaN
# 454                                 NaN                            NaN
# 455                                 NaN                            NaN
# 456                                 NaN                            NaN
# 457                                 NaN                            NaN
# 458                                 NaN                            NaN
# 459                                 NaN                            NaN
# 460                                 NaN                            NaN
# 461                                 NaN                            NaN
# 462                                 NaN                            NaN
# 463                                 NaN                            NaN
# 464                                 NaN                            NaN
# 465                                 NaN                            NaN
# 466                                 NaN                            NaN
# 467                                 NaN                            NaN
# 468                                 NaN                            NaN
# 469                                 NaN                            NaN
# 470                                 NaN                            NaN
# 471                                 NaN                            NaN
# 472                                 NaN                            NaN
# 473                                 NaN                            NaN
# 474                                 NaN                            NaN
# 475                                 NaN                            NaN
# 476                                 NaN                            NaN
# 477                                 NaN                            NaN
# 478                                 NaN                            NaN
# 479                                 NaN                            NaN
# 480                                 NaN                            NaN
# 481                                 NaN                            NaN
# 482                                 NaN                            NaN
# 483                                 NaN                            NaN
# 484                                 NaN                            NaN
# 485                                 NaN                            NaN
# 486                                 NaN                            NaN
# 487                                 NaN                            NaN
#
#     Economic activity status  Observation area  chn2021
# 438                      NaN          NaN  NaN      NaN
# 439                      NaN          NaN  NaN      NaN
# 440                      NaN          NaN  NaN      NaN
# 441                      NaN          NaN  NaN      NaN
# 442                      NaN          NaN  NaN      NaN
# 443                      NaN          NaN  NaN      NaN
# 444                      NaN          NaN  NaN      NaN
# 445                      NaN          NaN  NaN      NaN
# 446                      NaN          NaN  NaN      NaN
# 447                      NaN          NaN  NaN      NaN
# 448                      NaN          NaN  NaN      NaN
# 449                      NaN          NaN  NaN      NaN
# 450                      NaN          NaN  NaN      NaN
# 451                      NaN          NaN  NaN      NaN
# 452                      NaN          NaN  NaN      NaN
# 453                      NaN          NaN  NaN      NaN
# 454                      NaN          NaN  NaN      NaN
# 455                      NaN          NaN  NaN      NaN
# 456                      NaN          NaN  NaN      NaN
# 457                      NaN          NaN  NaN      NaN
# 458                      NaN          NaN  NaN      NaN
# 459                      NaN          NaN  NaN      NaN
# 460                      NaN          NaN  NaN      NaN
# 461                      NaN          NaN  NaN      NaN
# 462                      NaN          NaN  NaN      NaN
# 463                      NaN          NaN  NaN      NaN
# 464                      NaN          NaN  NaN      NaN
# 465                      NaN          NaN  NaN      NaN
# 466                      NaN          NaN  NaN      NaN
# 467                      NaN          NaN  NaN      NaN
# 468                      NaN          NaN  NaN      NaN
# 469                      NaN          NaN  NaN      NaN
# 470                      NaN          NaN  NaN      NaN
# 471                      NaN          NaN  NaN      NaN
# 472                      NaN          NaN  NaN      NaN
# 473                      NaN          NaN  NaN      NaN
# 474                      NaN          NaN  NaN      NaN
# 475                      NaN          NaN  NaN      NaN
# 476                      NaN          NaN  NaN      NaN
# 477                      NaN          NaN  NaN      NaN
# 478                      NaN          NaN  NaN      NaN
# 479                      NaN          NaN  NaN      NaN
# 480                      NaN          NaN  NaN      NaN
# 481                      NaN          NaN  NaN      NaN
# 482                      NaN          NaN  NaN      NaN
# 483                      NaN          NaN  NaN      NaN
# 484                      NaN          NaN  NaN      NaN
# 485                      NaN          NaN  NaN      NaN
# 486                      NaN          NaN  NaN      NaN
# 487                      NaN          NaN  NaN      NaN

# %%
new_data = merged_data

# Fill missing values in the Observation column with zero
new_data['Observation'] = new_data['Observation'].fillna(0)

# Prepare for bivariate classification - divide both variables into tertiles (Low, Medium, High)
# For students: compute tertiles only using non-zero values
nonzero_students = new_data[new_data['Observation'] > 0]['Observation']
student_tertiles = [
    nonzero_students.quantile(0.33),
    nonzero_students.quantile(0.67)
]

# Compute tertiles for Residential Mobility Index (chn2021)
mobility_tertiles = [
    new_data['chn2021'].quantile(0.33),
    new_data['chn2021'].quantile(0.67)
]

# Define classification functions for each variable
def classify_students(value, tertiles):
    if value == 0:
        return 0  # No students
    elif value <= tertiles[0]:
        return 1  # Low
    elif value <= tertiles[1]:
        return 2  # Medium
    else:
        return 3  # High

def classify_mobility(value, tertiles):
    if value <= tertiles[0]:
        return 1  # Low
    elif value <= tertiles[1]:
        return 2  # Medium
    else:
        return 3  # High

# Apply classification to both variables
new_data['student_class'] = new_data['Observation'].apply(
    lambda x: classify_students(x, student_tertiles))
new_data['mobility_class'] = new_data['chn2021'].apply(
    lambda x: classify_mobility(x, mobility_tertiles))

# Create combined bivariate class: 0 for no students, 1–9 for all other combinations
# This enables plotting with a 3x3 bivariate color scheme
new_data['bivariate_class'] = new_data.apply(
    lambda row: 0 if row['student_class'] == 0 else
    row['student_class'] + (row['mobility_class'] - 1) * 3,
    axis=1)

# %%
# Define bivariate color scheme - include special color for zero-value areas
# Define colors: special color for no students, then the 3x3 bivariate scheme
bivariate_colors = [
    '#f7f7f7',  # No students - Very light gray (almost white)
    '#0063D1',  # Low students-Low mobility - Very light blue
    '#FFD6A5',  # Medium students-Low mobility - Light blue
    '#FFAA5E',  # High students-Low mobility - Medium blue
    '#2785FF',  # Low students-Medium mobility - Very light yellow
    '#FFF4E6',  # Medium students-Medium mobility - Light blue-gray
    '#FF8427',  # High students-Medium mobility - Blue-green
    '#5EB0FF',  # Low students-High mobility - Orange
    '#A5D8FF',  # Medium students-High mobility - Medium blue
    '#D96400'   # High students-High mobility
]

# Map categories to colors
color_dict = {i: color for i, color in enumerate(bivariate_colors)}

# Draw the bivariate map
fig, ax = plt.subplots(figsize=(15, 12))
new_data.plot(column='bivariate_class',
                categorical=True,
                cmap=colors.ListedColormap(bivariate_colors),
                linewidth=0.3,
                edgecolor='#333333',
                ax=ax)

# Add hatching pattern for areas with no students
no_data_areas = new_data[new_data['student_class'] == 0]
no_data_areas.plot(ax=ax, facecolor="none", edgecolor='gray',
                     hatch='///', linewidth=1, alpha=0.9)

# Create a grid for the 3x3 bivariate legend
legend_ax = fig.add_axes([0.15, 0.19, 0.15, 0.15])
legend_ax.set_xlim(0, 3)
legend_ax.set_ylim(0, 3)

# Add color squares
for i in range(3):
    for j in range(3):
        idx = i * 3 + j + 1  # +1 because we have a special category at index 0
        legend_ax.add_patch(plt.Rectangle((j, i), 1, 1, facecolor=bivariate_colors[idx], edgecolor='white'))

# Remove legend axes
legend_ax.set_xticks([])
legend_ax.set_yticks([])

# Add legend labels
legend_ax.text(1.5, -0.45, 'Economically Inactive Students', ha='center', va='center', fontsize=10)
legend_ax.text(-0.45, 1.5, 'Residential Mobility Index', ha='center', va='center', rotation=90, fontsize=10)

# Add directional arrows
legend_ax.text(0.5, -0.2, 'Low', ha='center', va='center', fontsize=8)
legend_ax.text(2.5, -0.2, 'High', ha='center', va='center', fontsize=8)
legend_ax.text(-0.2, 0.5, 'Low', ha='center', va='center', fontsize=8)
legend_ax.text(-0.2, 2.5, 'High', ha='center', va='center', fontsize=8)

# Add a special legend for areas with no students
no_data_patch = mpatches.Patch(facecolor=bivariate_colors[0], edgecolor='gray', hatch='///', label='No Data')
no_data_legend_ax = fig.add_axes([0.11, 0.36, 0.15, 0.02])
no_data_legend_ax.axis('off')
no_data_legend=no_data_legend_ax.legend(handles=[no_data_patch], loc='center' ,
    frameon=True,
    framealpha=0.9,
    title='Special Areas')

# Add title and annotations
ax.set_title('Spatial relationship between Economically Inactive Students and Residential Mobility Index', fontsize=20, loc='center')

plt.figtext(0.12, 0.1,
           "Data source: Census 2021 https://www.ons.gov.uk/census/maps/ & Consumer Data Research Centre https://data.cdrc.ac.uk/dataset/cdrc-residential-mobility-index",
           fontsize=10)
ax.set_axis_off()
add_north_arrow(ax=ax, scale=.75, xlim_pos=0.1, ylim_pos=.85, color='#000', text_scaler=2, text_yT=-1.25)

# Add a scale bar
scalebar = ScaleBar(
    1, "m",
    location="lower left"
)
ax.add_artist(scalebar)

plt.show()

# %% [markdown]
# The non-spatial visualization above supports the conclusion that economically inactive students are more strongly affected by the residential mobility index in Leeds. The merged dataset must be cleaned to explore the spatial relationship between economically inactive students and the residential mobility index. First, only the data, including economically inactive students, was required to be retained, and this data was joined with the LSOA shapefile for Leeds through the LSOA code. The newly merged dataset exploration revealed that 50 LSOAs have missing values for both economically inactive student data and residential mobility data. In order to maintain the authenticity of the spatial visualization in the next step, these data were retained, and these special areas were marked during the visualization process. This spatial visualization applies a bivariate choropleth map to illustrate the spatial relationship between the two variables. This map can efficiently show the spatial relationship between two variables by dividing each variable's data into three categories and using a combination matrix legend with nine colors to facilitate displaying the associations between variables [10]. Before the spatial visualization, the newly merged dataset needs to be processed by classifying both student numbers and the residential mobility index into categories using tertiles, and then appending the classified data to the table. This classification method is less influenced by extreme values and has relatively high accuracy, making it suitable for the data in this study [11]. The classified data were calculated to classify each LSOA into nine classes. Additionally, missing values were assigned a zero value to ensure they could be identified and marked on the map. The final classified data were used for spatial visualization, and to enhance accessibility and ensure readability for all audiences, a high-contrast color scheme consisting of five shades of orange and four shades of blue was adopted [12]. According to the map, areas with high residential mobility index and large economically inactive student populations are primarily concentrated in the central-western part of Leeds, with similar patterns also observed in some northeastern and eastern coastal areas. Conversely, areas with lower residential mobility index and fewer students are mainly located in the east part of Leeds and some areas of the southwest and northwest.

# %% [markdown]
# ## References
# <p><a href="https://data.cdrc.ac.uk/dataset/cdrc-residential-mobility-index">[1]</a>Consumer Data Research Centre, CDRC Residential Mobility Index</p>
# <p><a href="https://link.springer.com/book/10.1007/978-3-031-01892-3">[2]</a>Foundations of Data Quality Management</p>
# <p><a href=" https://seaborn.pydata.org/generated/seaborn.catplot.html">[3]</a>seaborn.catplot</p>
# <p><a href="https://journals.plos.org/plosmedicine/article?id=10.1371/journal.pmed.0020267">[4]</a>Data Cleaning: Detecting, Diagnosing, and Editing Data Abnormalities</p>
# <p><a href="https://seaborn.pydata.org/generated/seaborn.jointplot.html">[5]</a>seaborn.jointplot</p>
# <p><a href=" https://seaborn.pydata.org/generated/seaborn.lmplot.html">[6]</a>seaborn.lmplot</p>
# <p><a href="https://www.investopedia.com/terms/r/regression.asp">[7]</a>Regression: Definition, Analysis, Calculation, and Example</p>
# <p><a href="https://www.canva.com/design/DAGezI_-Iwk/n7L3mkv-SpB6FhA0ZL2FeA/view?utm_content=DAGezI_-Iwk&utm_campaign=designshare&utm_medium=link2&utm_source=uniquelinks&utlId=heb7956f24c#29">[8]</a>GEOG5990M course materials</p>
# <p><a href="https://www.color-blindness.com/coblis-color-blindness-simulator/">[9]</a>Coblis —
# Color Blindness Simulator</p>
# <p><a href="https://leeds.primo.exlibrisgroup.com/discovery/fulldisplay?docid=cdi_proquest_journals_2554544045&context=PC&vid=44LEE_INST:VU1&lang=en&search_scope=My_Inst_CI_not_ebsco&adaptor=Primo%20Central&tab=AlmostEverything&query=any,contains,Geo-Spatial%20Analysis%20of%20Population%20Density%20and%20Annual%20Income%20to%20Identify%20Large-Scale%20Socio-Demographic%20Disparities&pfilter=rtype,exact,articles&offset=0">[10]</a>Geo-Spatial Analysis of Population Density and Annual Income to Identify Large-Scale Socio-Demographic Disparities</p>
# <p><a href="https://leeds.primo.exlibrisgroup.com/discovery/fulldisplay?docid=cdi_wiley_primary_10_1111_1467_8306_00310_ANNA310&context=PC&vid=44LEE_INST:VU1&lang=en&search_scope=My_Inst_CI_not_ebsco&adaptor=Primo%20Central&tab=AlmostEverything&query=any,contains,Evaluation%20of%20methods%20for%20classifying%20epidemiological%20data%20on%20choropleth%20maps%20in%20series.&sortby=rank&pfilter=rtype,exact,articles&offset=0">[11]</a>Evaluation of Methods for Classifying Epidemiological Data on Choropleth Maps in Series</p>
# <p><a href="https://www.canva.com/design/DAGezI_-Iwk/n7L3mkv-SpB6FhA0ZL2FeA/view?utm_content=DAGezI_-Iwk&utm_campaign=designshare&utm_medium=link2&utm_source=uniquelinks&utlId=heb7956f24c#29">[12]</a>GEOG5990M course materials</p>

# %% [markdown]
# # **Acknowledgements**
# I acknowledge the use of ChatGPT-4o (Open AI, https://chat.openai.com/) to support cleaning data for spatial visualization
#
# I acknowledge the use of ChatGPT-4o (Open AI, https://chat.openai.com/) to support spatial visualization
